# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

# %%
class_list = model.names 
#class_list

# %%
# Open the video file
cap = cv2.VideoCapture('C:/Users/hi/yolo11/demo_detect_track_count_multiple_vehicles/test_videos/4.mp4')

# %%
#Detection text form

import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

class_list = model.names 
#class_list

# Open the video file
cap = cv2.VideoCapture('C:/Users/hi/yolo11/demo_detect_track_count_multiple_vehicles/test_videos/4.mp4')

line_y_red = 430  # Red line position

# Dictionary to store object counts by class
class_counts = defaultdict(int)

# Dictionary to keep track of object IDs that have crossed the line
crossed_ids = set()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes = [1,2,3,5,6,7]) 
    #print(results)

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (690, line_y_red), (1130, line_y_red), (0, 0, 255), 3)
        #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


        

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2            

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 


            # Check if the object has crossed the red line
            if cy > line_y_red and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1


        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    
    
    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)    
    
    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 749.9ms
# Speed: 4.7ms preprocess, 749.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 motorcycles, 3 buss, 1 truck, 747.4ms
# Speed: 4.0ms preprocess, 747.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 motorcycles, 3 buss, 1 truck, 879.3ms
# Speed: 3.3ms preprocess, 879.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 motorcycles, 3 buss, 1 truck, 647.6ms
# Speed: 8.2ms preprocess, 647.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 1 truck, 609.8ms
# Speed: 3.4ms preprocess, 609.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 motorcycles, 3 buss, 1 truck, 531.5ms
# Speed: 2.9ms preprocess, 531.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
#Input Detection video

import cv2
from IPython.display import display, clear_output
from PIL import Image
import time

# Load video
video_path = 'C:/Users/hi/yolo11/demo_detect_track_count_multiple_vehicles/test_videos/4.mp4'
cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    # Resize (optional)
    frame = cv2.resize(frame, (640, 360))

    # Convert BGR → RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Convert to image
    img = Image.fromarray(frame_rgb)

    # Clear previous frame
    clear_output(wait=True)

    # Display frame
    display(img)

    # Control speed (important)
    time.sleep(0.03)

cap.release()
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 11
#       7 video_path = 'C:/Users/hi/yolo11/demo_detect_track_count_multiple_vehicles/test_videos/4.mp4'
#       8 cap = cv2.VideoCapture(video_path)
#       9
#      10 while cap.isOpened():
# ---> 11     ret, frame = cap.read()
#      12
#      13     if not ret:
#      14         break
#
# KeyboardInterrupt:

# %%
#Detection video

import cv2
from ultralytics import YOLO
from IPython.display import display, clear_output
from PIL import Image
import time

# Load YOLO model
model = YOLO('yolo11l.pt')

# Load video
cap = cv2.VideoCapture('C:/Users/hi/yolo11/demo_detect_track_count_multiple_vehicles/test_videos/4.mp4')

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    frame=cv2.resize(frame,(640,360))

    # Run detection
    results = model.track(frame,persist=True,conf=0.4)

    # ⭐ THIS LINE DRAWS BOXES
    annotated_frame = results[0].plot()

    # Convert BGR → RGB
    rgb = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

    img = Image.fromarray(rgb)

    clear_output(wait=True)
    display(img)

    time.sleep(0.001)

cap.release()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 22
#      18
#      19     frame=cv2.resize(frame,(640,360))
#      20
#      21     # Run detection
# ---> 22     results = model.track(frame,persist=True,conf=0.4)
#      23
#      24     # ⭐ THIS LINE DRAWS BOXES
#      25     annotated_frame = results[0].plot()
#
# File ~\myvenv\Lib\site-packages\ultralytics\engine\model.py:579, in Model.track(self, source, stream, persist, **kwargs)
#     577 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     578 kwargs["mode"] = "track"
# --> 579 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~\myvenv\Lib\site-packages\ultralytics\engine\model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
# ...
